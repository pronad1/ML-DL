# %% [markdown]
# ### Perception demo

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../placement-dataset.csv')

# %%
print(df.shape)
df.head()
# Out:
# (100, 4)
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
sns.scatterplot(x='cgpa', y='iq', hue='placement', data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
X=df.iloc[:,1:3]
y=df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %% [markdown]
# The value of all weight

# %%
p.coef_
# Out:
# array([[1218.5, -193. ]])

# %% [markdown]
# The value of Bias

# %%
p.intercept_
# Out:
# array([-7.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# c:\Users\prose\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
