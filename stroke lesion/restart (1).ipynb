# %%
# =================================================================
# SOTA ISLES-2022: 5-Model Ensemble Training
# - Trains UNet, AttentionUnet, SegResNet, DynUNet, and DerNet3D
# - Averages predictions to push past the 84% SOTA barrier
# - Uses deterministic 70/15/15 train/val/test split (seed=42)
# - Tuned for exactly 22 epochs (11 hours) + 1 hour validation tuning
# =================================================================

import sys
import subprocess
import os
import glob
import random
from multiprocessing import Pool, cpu_count

def pip_install(packages):
    cmd = [sys.executable, "-m", "pip", "install", "--upgrade"] + packages
    subprocess.check_call(cmd)

# --- Ensure required packages ---
required = []
try:
    import monai  
except Exception:
    required.append("monai")

try:
    import sklearn  
except Exception:
    required.append("scikit-learn")

try:
    import SimpleITK  
except Exception:
    required.append("SimpleITK")

try:
    import einops
except Exception:
    required.append("einops")

if required:
    print("Installing missing packages:", required)
    pip_install(required)

# --- Standard imports ---
import numpy as np
import pandas as pd
import nibabel as nib
import SimpleITK as sitk
from scipy.ndimage import zoom, label, binary_closing
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from tqdm.auto import tqdm

import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import WeightedRandomSampler
from torch.amp import GradScaler, autocast

from monai.networks.nets import DynUNet, AttentionUnet, UNet, SegResNet
from monai.losses import DiceLoss, TverskyLoss
from monai.transforms import Compose, RandFlipd, RandGaussianNoised
from monai.metrics import DiceMetric

# Speed / backend tweaks
torch.backends.cudnn.benchmark = True

# ---------------- Config ----------------
SEARCH_ROOT = "/kaggle/input/datasets/orvile/isles-2022-brain-stoke-dataset/ISLES-2022/ISLES-2022" 
OUT_DIR = "/kaggle/working/checkpoints_improved"
CACHE_DIR = "/kaggle/working/preprocessed_cache"
os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(CACHE_DIR, exist_ok=True)

# Path to Colab SegResNet weights (Model #3 will load this)
PREV_SEGRESNET_WEIGHTS = "/kaggle/input/datasets/prosenjitmondol/fold-04/DERNet_best_val.pth"

CONFIG = {
    "in_channels": 3,
    "out_channels": 1,
    "lr": 1e-4,
    "epochs": 60,
    "batch_size": 1,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "spatial_multiple": 16,
    "seed": 42,
    "patch_size": (64, 128, 128),
    "lesion_patch_prob": 0.9,  
    "min_component_voxels": 50,
    "tta_transforms": ["flip_x", "flip_y", "flip_z"],
    "num_workers_train": 0,    # 0 completely prevents Kaggle multiprocessing crashes
    "num_workers_val": 0,      
    "validate_every": 1,
    "compile_models": False,
    "preload_to_ram": True,
    "apply_n4_in_preprocessing": False,
    "prefetch_factor": None    # Must be None when num_workers is 0
}
random.seed(CONFIG["seed"]); np.random.seed(CONFIG["seed"]); torch.manual_seed(CONFIG["seed"])

# ---------------- Utilities ----------------
def find_real_nii_file(path_pattern: str):
    matches = glob.glob(path_pattern, recursive=True)
    for path in matches:
        if os.path.isdir(path):
            nii_files = glob.glob(os.path.join(path, "**", "*.nii*"), recursive=True)
            if nii_files:
                return nii_files[0]
        elif path.endswith(".nii") or path.endswith(".nii.gz"):
            return path
    return None

def zscore_normalize(volume):
    v = volume.astype(np.float32)
    m = v.mean()
    s = v.std() if v.std() > 0 else 1.0
    return (v - m) / s

def pad_to_multiple_tensor(x: torch.Tensor, multiple: int):
    _, _, D, H, W = x.shape
    pad_d = (multiple - (D % multiple)) % multiple
    pad_h = (multiple - (H % multiple)) % multiple
    pad_w = (multiple - (W % multiple)) % multiple
    pad = (0, pad_w, 0, pad_h, 0, pad_d)
    if any([pad_d, pad_h, pad_w]):
        x = F.pad(x, pad, mode="constant", value=0)
    return x, pad

def unpad_tensor(x: torch.Tensor, pad):
    if pad is None:
        return x
    w_r = pad[1]; h_r = pad[3]; d_r = pad[5]
    D, H, W = x.shape[2], x.shape[3], x.shape[4]
    d_end = D - d_r if d_r != 0 else D
    h_end = H - h_r if h_r != 0 else H
    w_end = W - w_r if w_r != 0 else W
    return x[:, :, :d_end, :h_end, :w_end]

def pad_volume_to_multiple(vol, multiple):
    D, H, W = vol.shape
    pad_d = (multiple - (D % multiple)) % multiple
    pad_h = (multiple - (H % multiple)) % multiple
    pad_w = (multiple - (W % multiple)) % multiple
    if pad_d or pad_h or pad_w:
        vol = np.pad(vol, ((0,pad_d),(0,pad_h),(0,pad_w)), mode="constant", constant_values=0)
    return vol

def remove_small_components(pred_mask_np, min_voxels=50):
    labeled, n = label(pred_mask_np)
    out = np.zeros_like(pred_mask_np)
    for comp in range(1, n+1):
        comp_vox = (labeled == comp)
        if comp_vox.sum() >= min_voxels:
            out[comp_vox] = 1
    return out

# ---------------- Data pairing ----------------
def get_isles_dataframe(search_path: str):
    mask_files = glob.glob(os.path.join(search_path, "**", "*_msk.nii*"), recursive=True)
    data = []
    for mask_path in tqdm(mask_files, desc="Pairing modalities"):
        filename = os.path.basename(mask_path)
        parts = filename.split("_")
        if len(parts) < 2:
            continue
        case_id = parts[0]
        session_id = parts[1]
        if "derivatives" in mask_path:
            base_dir = mask_path.split("derivatives")[0]
        else:
            base_dir = os.path.dirname(os.path.dirname(mask_path)) + os.sep
        case_folder = os.path.join(base_dir, case_id, session_id)
        flair = find_real_nii_file(os.path.join(case_folder, "anat", "*FLAIR.nii*"))
        adc = find_real_nii_file(os.path.join(case_folder, "dwi", "*adc.nii*"))
        dwi = find_real_nii_file(os.path.join(case_folder, "dwi", "*dwi.nii*"))
        if flair and adc and dwi:
            data.append({"case_id": case_id, "flair": flair, "adc": adc, "dwi": dwi, "mask": mask_path})
    return pd.DataFrame(data)

# ---------------- Preprocessing worker ----------------
def preprocess_case_worker(args):
    idx, row, cache_path, apply_n4, multiple = args
    try:
        if os.path.exists(cache_path):
            return cache_path
        flair = nib.load(row["flair"]).get_fdata().astype(np.float32)
        adc = nib.load(row["adc"]).get_fdata().astype(np.float32)
        dwi = nib.load(row["dwi"]).get_fdata().astype(np.float32)
        mask = nib.load(row["mask"]).get_fdata().astype(np.float32)
        target_shape = mask.shape
        def resample(vol, target_shape, is_mask=False):
            if vol.shape == target_shape:
                return vol
            zoom_factors = [t / s for s, t in zip(vol.shape, target_shape)]
            order = 0 if is_mask else 1
            return zoom(vol, zoom_factors, order=order)
        flair = resample(flair, target_shape)
        adc = resample(adc, target_shape)
        dwi = resample(dwi, target_shape)
        mask = resample(mask, target_shape, is_mask=True)
        flair = zscore_normalize(flair)
        adc = zscore_normalize(adc)
        dwi = zscore_normalize(dwi)
        flair = pad_volume_to_multiple(flair, multiple)
        adc = pad_volume_to_multiple(adc, multiple)
        dwi = pad_volume_to_multiple(dwi, multiple)
        mask = pad_volume_to_multiple(mask, multiple)
        image = np.stack([flair, adc, dwi], axis=0).astype(np.float32)
        mask = (mask > 0.5).astype(np.float32)
        np.savez_compressed(cache_path, image=image, mask=mask)
        return cache_path
    except Exception:
        return None

# ---------------- Dataset with lesion-focused patching and RAM preload ----------------
class Stroke3DDataset(Dataset):
    def __init__(self, dataframe: pd.DataFrame, patch_size=None, lesion_patch_prob=0.9,
                 apply_n4=False, augment=False, preload_to_ram=True, n_proc=1):
        self.df = dataframe.reset_index(drop=True)
        self.patch_size = patch_size
        self.lesion_patch_prob = lesion_patch_prob
        self.apply_n4 = apply_n4
        self.augment = augment
        self.preload_to_ram = preload_to_ram
        self.n_proc = n_proc
        self.aug_transforms = Compose([
            RandFlipd(keys=["image", "mask"], prob=0.5, spatial_axis=0),
            RandFlipd(keys=["image", "mask"], prob=0.5, spatial_axis=1),
            RandFlipd(keys=["image", "mask"], prob=0.5, spatial_axis=2),
            RandGaussianNoised(keys=["image"], prob=0.1, mean=0.0, std=0.01)
        ])
        self.cache_paths = []
        for i, row in self.df.iterrows():
            case_id = row["case_id"]
            cache_name = f"{case_id}_{i}.npz"
            cache_path = os.path.join(CACHE_DIR, cache_name)
            self.cache_paths.append(cache_path)
        self._ensure_cache_parallel()
        self.memory_cache = None
        if self.preload_to_ram:
            self._preload_to_ram()

    def _ensure_cache_parallel(self):
        tasks = []
        multiple = CONFIG["spatial_multiple"]
        for i, row in self.df.iterrows():
            tasks.append((i, row, self.cache_paths[i], self.apply_n4, multiple))
        # Process sequentially to avoid multiprocessing issues in some Kaggle instances
        for t in tqdm(tasks, desc="Preprocessing cache"):
            preprocess_case_worker(t)

    def _preload_to_ram(self):
        self.memory_cache = []
        for p in tqdm(self.cache_paths, desc="Loading cache to RAM"):
            data = np.load(p)
            self.memory_cache.append((data["image"], data["mask"]))

    def __len__(self):
        return len(self.df)

    def sample_patch(self, image, mask):
        D, H, W = image.shape[1:]
        pd, ph, pw = self.patch_size
        if mask.sum() > 0 and random.random() < self.lesion_patch_prob:
            coords = np.argwhere(mask > 0)
            z, y, x = coords[np.random.randint(len(coords))]
            z0 = max(0, z - pd//2); z1 = z0 + pd
            y0 = max(0, y - ph//2); y1 = y0 + ph
            x0 = max(0, x - pw//2); x1 = x0 + pw
            if z1 > D: z1 = D; z0 = max(0, D - pd)
            if y1 > H: y1 = H; y0 = max(0, H - ph)
            if x1 > W: x1 = W; x0 = max(0, W - pw)
        else:
            z0 = random.randint(0, max(0, D - pd))
            y0 = random.randint(0, max(0, H - ph))
            x0 = random.randint(0, max(0, W - pw))
            z1, y1, x1 = z0 + pd, y0 + ph, x0 + pw
        img_patch = image[:, z0:z1, y0:y1, x0:x1]
        mask_patch = mask[z0:z1, y0:y1, x0:x1]
        return img_patch, mask_patch

    def __getitem__(self, idx):
        if self.memory_cache is not None:
            image, mask = self.memory_cache[idx]
        else:
            data = np.load(self.cache_paths[idx])
            image, mask = data["image"], data["mask"]
        if self.patch_size is not None:
            image, mask = self.sample_patch(image, mask)
        mask = np.expand_dims(mask, axis=0)
        if self.augment:
            d = {"image": image, "mask": mask}
            d = self.aug_transforms(d)
            image, mask = d["image"], d["mask"]
        return torch.from_numpy(image.astype(np.float32)), torch.from_numpy(mask.astype(np.float32))

# ---------------- DerNet3D ----------------
class DerNet3D(nn.Module):
    def __init__(self, in_channels=3, out_channels=1, base_filters=16):
        super().__init__()
        f = base_filters
        self.enc1 = nn.Sequential(
            nn.Conv3d(in_channels, f, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm3d(f),
            nn.ReLU(inplace=True)
        )
        self.block1 = nn.Sequential(
            nn.Conv3d(f, f, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm3d(f),
            nn.ReLU(inplace=True)
        )
        self.down1 = nn.Sequential(
            nn.Conv3d(f*2, f*2, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm3d(f*2),
            nn.ReLU(inplace=True)
        )
        self.block2 = nn.Sequential(
            nn.Conv3d(f*2, f*2, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm3d(f*2),
            nn.ReLU(inplace=True)
        )
        self.up1 = nn.ConvTranspose3d(f*2, f, kernel_size=2, stride=2)
        self.final = nn.Conv3d(f*2, out_channels, kernel_size=1)

    def forward(self, x):
        e1 = self.enc1(x)
        b1 = self.block1(e1)
        cat1 = torch.cat([e1, b1], dim=1)
        d1 = self.down1(cat1)
        b2 = self.block2(d1)
        u1 = self.up1(b2)
        if u1.shape[2:] != e1.shape[2:]:
            u1 = F.interpolate(u1, size=e1.shape[2:], mode="trilinear", align_corners=False)
        out_cat = torch.cat([u1, e1], dim=1)
        logits = self.final(out_cat)
        return logits

# ---------------- Model factory ----------------
def get_models(device):
    m1 = UNet(spatial_dims=3, in_channels=3, out_channels=1,
              channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2)).to(device)
    m2 = AttentionUnet(spatial_dims=3, in_channels=3, out_channels=1,
                       channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2)).to(device)
    m3 = SegResNet(spatial_dims=3, in_channels=3, out_channels=1, init_filters=16).to(device)
    m4 = DynUNet(
        spatial_dims=3, in_channels=3, out_channels=1,
        kernel_size=[[3,3,3]]*5, strides=[[1,1,1]] + [[2,2,2]]*4,
        upsample_kernel_size=[[2,2,2]]*4, filters=[16, 32, 64, 128, 256]
    ).to(device)
    m5 = DerNet3D(in_channels=3, out_channels=1, base_filters=16).to(device)
    models = [m1, m2, m3, m4, m5]
    return models

# ---------------- Focal Tversky Loss ----------------
class FocalTversky(nn.Module):
    def __init__(self, alpha=0.7, beta=0.3, gamma=0.75, smooth=1e-6):
        super().__init__()
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.smooth = smooth

    def forward(self, logits, target):
        probs = torch.sigmoid(logits)
        dims = (2,3,4)
        TP = (probs * target).sum(dim=dims)
        FP = (probs * (1 - target)).sum(dim=dims)
        FN = ((1 - probs) * target).sum(dim=dims)
        tversky = (TP + self.smooth) / (TP + self.alpha * FN + self.beta * FP + self.smooth)
        loss = (1 - tversky) ** self.gamma
        return loss.mean()

# ---------------- Validation (Ensemble) ----------------
def validate_ensemble(models, loader):
    for m in models: m.eval()
    dice_metric = DiceMetric(include_background=True, reduction="mean")
    all_f1s = []
    with torch.no_grad():
        for images, masks in tqdm(loader, desc="Validating", leave=False):
            images = images.to(CONFIG["device"], dtype=torch.float32)
            masks = masks.to(CONFIG["device"], dtype=torch.float32)
            if images.ndim == 4:
                images = images.unsqueeze(0); masks = masks.unsqueeze(0)
            images, pad = pad_to_multiple_tensor(images, CONFIG["spatial_multiple"])
            masks, _ = pad_to_multiple_tensor(masks, CONFIG["spatial_multiple"])
            preds = []
            for model in models:
                p = model(images)
                p = torch.sigmoid(p)
                if p.shape != masks.shape:
                    p = F.interpolate(p, size=masks.shape[2:], mode="trilinear", align_corners=False)
                preds.append(p)
            ensemble_pred = torch.mean(torch.stack(preds, dim=0), dim=0)
            final_mask = (ensemble_pred > 0.5).float()
            bin_masks = (masks > 0.5).float()
            try:
                dice_metric(y_pred=final_mask, y=bin_masks)
            except Exception:
                if final_mask.shape != bin_masks.shape:
                    final_mask = F.interpolate(final_mask, size=bin_masks.shape[2:], mode="nearest")
                    dice_metric(y_pred=final_mask, y=bin_masks)
                else:
                    raise
            final_mask_unpadded = unpad_tensor(final_mask, pad)
            bin_masks_unpadded = unpad_tensor(bin_masks, pad)
            fp = final_mask_unpadded.cpu().numpy()
            gt = bin_masks_unpadded.cpu().numpy()
            B = fp.shape[0]
            for b in range(B):
                y_pred_flat = fp[b].ravel()
                y_true_flat = gt[b].ravel()
                if y_true_flat.sum() == 0 and y_pred_flat.sum() == 0:
                    f1 = 1.0
                else:
                    f1 = f1_score(y_true_flat, y_pred_flat, zero_division=0)
                all_f1s.append(f1)
    mean_dice = dice_metric.aggregate().item()
    dice_metric.reset()
    mean_f1 = float(np.mean(all_f1s)) if len(all_f1s) > 0 else 0.0
    return mean_dice, mean_f1

# ---------------- Post-Processing Tuning ----------------
def collect_val_predictions(models, loader):
    for m in models: m.eval()
    preds_per_model = [[] for _ in models]
    gts = []
    with torch.no_grad():
        for images, masks in tqdm(loader, desc="Collecting val preds", leave=False):
            images = images.to(CONFIG["device"], dtype=torch.float32)
            masks = masks.to(CONFIG["device"], dtype=torch.float32)
            if images.ndim == 4:
                images = images.unsqueeze(0); masks = masks.unsqueeze(0)
            images, pad = pad_to_multiple_tensor(images, CONFIG["spatial_multiple"])
            masks, _ = pad_to_multiple_tensor(masks, CONFIG["spatial_multiple"])
            for i, model in enumerate(models):
                p = torch.sigmoid(model(images))
                if p.shape != masks.shape:
                    p = F.interpolate(p, size=masks.shape[2:], mode="trilinear", align_corners=False)
                p_unp = unpad_tensor(p, pad)
                preds_per_model[i].append(p_unp.cpu().numpy()[0,0])
            gt_unp = unpad_tensor(masks, pad)
            gts.append(gt_unp.cpu().numpy()[0,0].astype(np.uint8))
    preds_per_model = [np.stack(lst, axis=0) for lst in preds_per_model]  
    return preds_per_model, gts

def tune_threshold_and_minvox(preds_per_model, gts, thresholds=np.linspace(0.3,0.7,21), min_vox_list=[10,25,50,100]):
    best = (0.5, 50, -1.0)
    N = preds_per_model[0].shape[0]
    for t in thresholds:
        for mv in min_vox_list:
            f1s = []
            for i in range(N):
                ensemble = np.mean([preds_per_model[m][i] for m in range(len(preds_per_model))], axis=0)
                bin_mask = (ensemble > t).astype(np.uint8)
                if mv > 0:
                    bin_mask = remove_small_components(bin_mask, min_voxels=mv)
                bin_mask = binary_closing(bin_mask, structure=np.ones((3,3,3))).astype(np.uint8)
                f1s.append(f1_score(gts[i].ravel(), bin_mask.ravel(), zero_division=0))
            mean_f1 = float(np.mean(f1s))
            if mean_f1 > best[2]:
                best = (t, mv, mean_f1)
    return best  

# ---------------- Evaluation ----------------
def evaluate_and_save_per_case_with_params(models, loader, df_subset, out_dir="/kaggle/working/eval_outputs",
                                           save_nifti=True, threshold=0.5, min_vox=50):
    os.makedirs(out_dir, exist_ok=True)
    for m in models: m.eval()
    dice_metric = DiceMetric(include_background=True, reduction="mean")
    records = []
    with torch.no_grad():
        for idx, (img, msk) in enumerate(tqdm(loader, desc="Test Eval")):
            case_id = df_subset.iloc[idx]["case_id"] if "case_id" in df_subset.columns else f"case_{idx}"
            images = img.to(CONFIG["device"], dtype=torch.float32)
            masks = msk.to(CONFIG["device"], dtype=torch.float32)
            if images.ndim == 4:
                images = images.unsqueeze(0); masks = masks.unsqueeze(0)
            images, pad = pad_to_multiple_tensor(images, CONFIG["spatial_multiple"])
            masks, _ = pad_to_multiple_tensor(masks, CONFIG["spatial_multiple"])
            preds = []
            for model in models:
                p = torch.sigmoid(model(images))
                if p.shape != masks.shape:
                    p = F.interpolate(p, size=masks.shape[2:], mode="trilinear", align_corners=False)
                preds.append(p)
            ensemble = torch.mean(torch.stack(preds, dim=0), dim=0)
            pred_bin = (ensemble > threshold).float()
            gt_bin = (masks > 0.5).float()
            try:
                dice_metric(y_pred=pred_bin, y=gt_bin)
            except Exception:
                if pred_bin.shape != gt_bin.shape:
                    pred_bin = F.interpolate(pred_bin, size=gt_bin.shape[2:], mode="nearest")
                    dice_metric(y_pred=pred_bin, y=gt_bin)
                else:
                    raise
            pred_unp = unpad_tensor(pred_bin, pad)
            gt_unp = unpad_tensor(gt_bin, pad)
            pred_np = pred_unp.cpu().numpy()[0,0].astype(np.uint8)
            gt_np = gt_unp.cpu().numpy()[0,0].astype(np.uint8)
            if min_vox > 0:
                pred_np = remove_small_components(pred_np, min_voxels=min_vox)
            pred_np = binary_closing(pred_np, structure=np.ones((3,3,3))).astype(np.uint8)
            y_pred_flat = pred_np.ravel()
            y_true_flat = gt_np.ravel()
            if y_true_flat.sum() == 0 and y_pred_flat.sum() == 0:
                f1 = 1.0
            else:
                f1 = f1_score(y_true_flat, y_pred_flat, zero_division=0)
            records.append({"case_id": case_id, "f1": float(f1)})
            if save_nifti:
                mask_path = df_subset.iloc[idx]["mask"]
                try:
                    ref_nii = nib.load(mask_path)
                    affine = ref_nii.affine
                except Exception:
                    affine = np.eye(4)
                out_path = os.path.join(out_dir, f"{case_id}_pred.nii.gz")
                nib.save(nib.Nifti1Image(pred_np.astype(np.uint8), affine), out_path)
    mean_dice = dice_metric.aggregate().item()
    dice_metric.reset()
    df_out = pd.DataFrame(records)
    df_out["dice"] = float(mean_dice)
    csv_path = os.path.join(out_dir, "per_case_metrics.csv")
    df_out.to_csv(csv_path, index=False)
    return float(mean_dice), float(df_out["f1"].mean()), csv_path

# ---------------- Main ----------------
if __name__ == "__main__":
    print(f"🚀 Initializing Kaggle 12H 5-Model Ensemble Engine | Epochs: {CONFIG['epochs']}")
    df = get_isles_dataframe(SEARCH_ROOT)
    if len(df) == 0:
        raise RuntimeError("No valid cases found. Check file naming and folder structure.")
    train_df, temp_df = train_test_split(df, test_size=0.3, random_state=CONFIG["seed"])
    val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=CONFIG["seed"])

    train_ds = Stroke3DDataset(train_df.reset_index(drop=True), patch_size=CONFIG["patch_size"],
                               lesion_patch_prob=CONFIG["lesion_patch_prob"],
                               apply_n4=CONFIG["apply_n4_in_preprocessing"], augment=True,
                               preload_to_ram=CONFIG["preload_to_ram"], n_proc=1)
    val_ds = Stroke3DDataset(val_df.reset_index(drop=True), patch_size=CONFIG["patch_size"],
                             lesion_patch_prob=0.0, apply_n4=CONFIG["apply_n4_in_preprocessing"],
                             augment=False, preload_to_ram=CONFIG["preload_to_ram"], n_proc=1)
    test_ds = Stroke3DDataset(test_df.reset_index(drop=True), patch_size=None,
                              lesion_patch_prob=0.0, apply_n4=CONFIG["apply_n4_in_preprocessing"],
                              augment=False, preload_to_ram=CONFIG["preload_to_ram"], n_proc=1)

    weights = []
    for i in range(len(train_ds)):
        if train_ds.memory_cache is not None:
            _, mask = train_ds.memory_cache[i]
        else:
            data = np.load(train_ds.cache_paths[i])
            mask = data["mask"]
        weights.append(5.0 if mask.sum() > 0 else 1.0)  
    sampler = WeightedRandomSampler(weights, num_samples=len(weights), replacement=True)

    train_loader = DataLoader(train_ds, batch_size=CONFIG["batch_size"], sampler=sampler,
                              num_workers=CONFIG["num_workers_train"], pin_memory=True,
                              persistent_workers=False, prefetch_factor=CONFIG["prefetch_factor"]) 
    val_loader = DataLoader(val_ds, batch_size=CONFIG["batch_size"], shuffle=False,
                            num_workers=CONFIG["num_workers_val"], pin_memory=True,
                            persistent_workers=False, prefetch_factor=CONFIG["prefetch_factor"]) 
    test_loader = DataLoader(test_ds, batch_size=CONFIG["batch_size"], shuffle=False,
                             num_workers=CONFIG["num_workers_val"], pin_memory=True,
                             persistent_workers=False, prefetch_factor=CONFIG["prefetch_factor"]) 

    models = get_models(CONFIG["device"])
    
    # --- LOAD PREVIOUS SEGRESNET WEIGHTS ---
    if os.path.exists(PREV_SEGRESNET_WEIGHTS):
        print(f"\n📥 Loading previous SegResNet weights from {PREV_SEGRESNET_WEIGHTS}")
        try:
            models[2].load_state_dict(torch.load(PREV_SEGRESNET_WEIGHTS, map_location=CONFIG["device"]))
            print("✅ SegResNet weights successfully loaded! Model 3 will carry the ensemble.")
        except Exception as e:
            print("⚠️ Architecture mismatch (Probably loaded DERNet instead of SegResNet). Training from scratch.")
    
    optimizers = [torch.optim.Adam(m.parameters(), lr=CONFIG["lr"]) for m in models]
    schedulers = [torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=max(1, CONFIG["epochs"])) for opt in optimizers]
    
    focal = FocalTversky(alpha=0.7, beta=0.3, gamma=0.75)
    bce = torch.nn.BCEWithLogitsLoss()
    def loss_fn(pred_logits, target):
        return 0.7 * focal(pred_logits, target) + 0.3 * bce(pred_logits, target)

    scaler = GradScaler('cuda') if torch.cuda.is_available() else None

    best_val_dice = -1.0
    best_epoch = -1

    for epoch in range(CONFIG["epochs"]):
        print(f"\nEpoch {epoch+1}/{CONFIG['epochs']}")
        for i, model in enumerate(models):
            model.train()
            optimizer = optimizers[i]
            total_loss = 0.0
            n_batches = 0
            desc = f"Epoch {epoch+1} - Train model {i}"
            for images, masks in tqdm(train_loader, desc=desc, leave=False):
                images = images.to(CONFIG["device"], dtype=torch.float32)
                masks = masks.to(CONFIG["device"], dtype=torch.float32)
                if images.ndim == 4:
                    images = images.unsqueeze(0); masks = masks.unsqueeze(0)
                images, pad = pad_to_multiple_tensor(images, CONFIG["spatial_multiple"])
                masks, _ = pad_to_multiple_tensor(masks, CONFIG["spatial_multiple"])
                optimizer.zero_grad()
                if scaler:
                    with autocast('cuda'):
                        output = model(images)
                        loss = loss_fn(output, masks)
                    scaler.scale(loss).backward()
                    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
                    scaler.step(optimizer)
                    scaler.update()
                else:
                    output = model(images)
                    loss = loss_fn(output, masks)
                    loss.backward()
                    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
                    optimizer.step()
                total_loss += loss.item()
                n_batches += 1
            avg_loss = total_loss / max(1, n_batches)
            print(f"Model {i} train loss: {avg_loss:.4f}")

        if (epoch + 1) % CONFIG["validate_every"] == 0:
            val_dice, val_f1 = validate_ensemble(models, val_loader)
            print(f"Validation - Dice: {val_dice:.4f} | F1: {val_f1:.4f}")
            for sch in schedulers: sch.step()
            if val_dice > best_val_dice + 1e-4:
                best_val_dice = val_dice
                best_epoch = epoch + 1
                for i, m in enumerate(models):
                    torch.save(m.state_dict(), os.path.join(OUT_DIR, f"best_model_{i}.pth"))
                print(f"--- New Best Ensemble Saved (epoch {best_epoch}) ---")
            else:
                print("No improvement this validation step.")
        else:
            for sch in schedulers: sch.step()

    for i, m in enumerate(models):
        ckpt = os.path.join(OUT_DIR, f"best_model_{i}.pth")
        if os.path.exists(ckpt):
            m.load_state_dict(torch.load(ckpt, map_location=CONFIG["device"]))
            print(f"Loaded checkpoint: {ckpt}")

    print("Collecting validation predictions for tuning...")
    preds_per_model, gts = collect_val_predictions(models, val_loader)
    print("Tuning threshold and min-component size on validation set...")
    best_thresh, best_minvox, best_score = tune_threshold_and_minvox(preds_per_model, gts,
                                                                     thresholds=np.linspace(0.3,0.7,21),
                                                                     min_vox_list=[10,25,50,100])
    print(f"Best threshold: {best_thresh:.3f}, best min_vox: {best_minvox}, val F1: {best_score:.4f}")

    print("\nEvaluating best ensemble on test set with tuned params...")
    test_dice, test_f1, csv_path = evaluate_and_save_per_case_with_params(models, test_loader,
                                                                          test_df.reset_index(drop=True),
                                                                          out_dir="/kaggle/working/eval_outputs",
                                                                          save_nifti=True,
                                                                          threshold=best_thresh,
                                                                          min_vox=best_minvox)
    print(f"Test Dice: {test_dice:.4f} | Test F1: {test_f1:.4f}")
    print(f"Per-case metrics saved to: {csv_path}")

if __name__ == "__main__":
    run()
# Out:
# Installing missing packages: ['monai']
# Collecting monai
#   Downloading monai-1.5.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3.0,>=1.24 in /usr/local/lib/python3.12/dist-packages (from monai) (2.0.2)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from monai) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.1->monai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.1->monai) (3.0.3)
# Downloading monai-1.5.2-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 28.2 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-1.5.2
# <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2026-03-16 23:08:04.304292: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773702484.484531      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773702484.538438      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773702484.993494      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773702484.993531      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773702484.993534      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773702484.993537      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🚀 Initializing Kaggle 12H 5-Model Ensemble Engine | Epochs: 60
# Pairing modalities:   0%|          | 0/250 [00:00<?, ?it/s]
# Preprocessing cache:   0%|          | 0/175 [00:00<?, ?it/s]
# Loading cache to RAM:   0%|          | 0/175 [00:00<?, ?it/s]
# Preprocessing cache:   0%|          | 0/37 [00:00<?, ?it/s]
# Loading cache to RAM:   0%|          | 0/37 [00:00<?, ?it/s]
# Preprocessing cache:   0%|          | 0/38 [00:00<?, ?it/s]
# Loading cache to RAM:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 1/60
# Epoch 1 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.8379
# Epoch 1 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.8620
# Epoch 1 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7955
# Epoch 1 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.9154
# Epoch 1 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.8431
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.2757 | F1: 0.2682
# --- New Best Ensemble Saved (epoch 1) ---
#
# Epoch 2/60
# Epoch 2 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.7796
# Epoch 2 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.8363
# Epoch 2 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7701
# Epoch 2 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.8452
# Epoch 2 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.7737
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.3381 | F1: 0.3290
# --- New Best Ensemble Saved (epoch 2) ---
#
# Epoch 3/60
# Epoch 3 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.7490
# Epoch 3 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.8221
# Epoch 3 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7531
# Epoch 3 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.8192
# Epoch 3 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.7251
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.3973 | F1: 0.3865
# --- New Best Ensemble Saved (epoch 3) ---
#
# Epoch 4/60
# Epoch 4 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.7312
# Epoch 4 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.8128
# Epoch 4 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7468
# Epoch 4 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.8053
# Epoch 4 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.6957
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.3561 | F1: 0.3735
# No improvement this validation step.
#
# Epoch 5/60
# Epoch 5 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.7174
# Epoch 5 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.8087
# Epoch 5 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7399
# Epoch 5 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7988
# Epoch 5 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.6726
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.3728 | F1: 0.3527
# No improvement this validation step.
#
# Epoch 6/60
# Epoch 6 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.7100
# Epoch 6 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.8044
# Epoch 6 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7299
# Epoch 6 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7907
# Epoch 6 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.6551
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.4396 | F1: 0.4158
# --- New Best Ensemble Saved (epoch 6) ---
#
# Epoch 7/60
# Epoch 7 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.7044
# Epoch 7 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7944
# Epoch 7 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7134
# Epoch 7 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7760
# Epoch 7 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.6198
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.3744 | F1: 0.3643
# No improvement this validation step.
#
# Epoch 8/60
# Epoch 8 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6907
# Epoch 8 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7897
# Epoch 8 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.7096
# Epoch 8 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7643
# Epoch 8 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.5984
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.4326 | F1: 0.4326
# No improvement this validation step.
#
# Epoch 9/60
# Epoch 9 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6849
# Epoch 9 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7793
# Epoch 9 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.6923
# Epoch 9 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7490
# Epoch 9 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.5613
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.4408 | F1: 0.4170
# --- New Best Ensemble Saved (epoch 9) ---
#
# Epoch 10/60
# Epoch 10 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6685
# Epoch 10 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7689
# Epoch 10 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.6784
# Epoch 10 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7340
# Epoch 10 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.5322
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.4345 | F1: 0.4227
# No improvement this validation step.
#
# Epoch 11/60
# Epoch 11 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6597
# Epoch 11 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7536
# Epoch 11 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.6643
# Epoch 11 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7257
# Epoch 11 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.5170
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.4807 | F1: 0.4288
# --- New Best Ensemble Saved (epoch 11) ---
#
# Epoch 12/60
# Epoch 12 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6449
# Epoch 12 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7480
# Epoch 12 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.6442
# Epoch 12 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.7133
# Epoch 12 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4809
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.4818 | F1: 0.4688
# --- New Best Ensemble Saved (epoch 12) ---
#
# Epoch 13/60
# Epoch 13 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6335
# Epoch 13 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7421
# Epoch 13 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.6230
# Epoch 13 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6911
# Epoch 13 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4832
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.4983 | F1: 0.4848
# --- New Best Ensemble Saved (epoch 13) ---
#
# Epoch 14/60
# Epoch 14 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6223
# Epoch 14 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7198
# Epoch 14 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.5934
# Epoch 14 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6788
# Epoch 14 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4508
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5057 | F1: 0.5191
# --- New Best Ensemble Saved (epoch 14) ---
#
# Epoch 15/60
# Epoch 15 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5876
# Epoch 15 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7157
# Epoch 15 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.5501
# Epoch 15 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6714
# Epoch 15 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4478
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5564 | F1: 0.5564
# --- New Best Ensemble Saved (epoch 15) ---
#
# Epoch 16/60
# Epoch 16 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.6020
# Epoch 16 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7116
# Epoch 16 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.5689
# Epoch 16 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6595
# Epoch 16 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4075
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5050 | F1: 0.4914
# No improvement this validation step.
#
# Epoch 17/60
# Epoch 17 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5828
# Epoch 17 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7099
# Epoch 17 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.5528
# Epoch 17 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6463
# Epoch 17 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4369
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5414 | F1: 0.5268
# No improvement this validation step.
#
# Epoch 18/60
# Epoch 18 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5779
# Epoch 18 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.7045
# Epoch 18 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.5142
# Epoch 18 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6393
# Epoch 18 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4275
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5522 | F1: 0.5373
# No improvement this validation step.
#
# Epoch 19/60
# Epoch 19 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5680
# Epoch 19 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6926
# Epoch 19 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4951
# Epoch 19 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6324
# Epoch 19 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3950
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5803 | F1: 0.5803
# --- New Best Ensemble Saved (epoch 19) ---
#
# Epoch 20/60
# Epoch 20 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5465
# Epoch 20 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6900
# Epoch 20 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4941
# Epoch 20 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6143
# Epoch 20 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4043
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5448 | F1: 0.5448
# No improvement this validation step.
#
# Epoch 21/60
# Epoch 21 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5365
# Epoch 21 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6884
# Epoch 21 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4995
# Epoch 21 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6083
# Epoch 21 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4030
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5990 | F1: 0.5774
# --- New Best Ensemble Saved (epoch 21) ---
#
# Epoch 22/60
# Epoch 22 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5309
# Epoch 22 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6825
# Epoch 22 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4586
# Epoch 22 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6076
# Epoch 22 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4134
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6078 | F1: 0.6078
# --- New Best Ensemble Saved (epoch 22) ---
#
# Epoch 23/60
# Epoch 23 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5212
# Epoch 23 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6672
# Epoch 23 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4240
# Epoch 23 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.6032
# Epoch 23 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4211
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5485 | F1: 0.5337
# No improvement this validation step.
#
# Epoch 24/60
# Epoch 24 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5319
# Epoch 24 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6633
# Epoch 24 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4548
# Epoch 24 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5949
# Epoch 24 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3951
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5706 | F1: 0.5706
# No improvement this validation step.
#
# Epoch 25/60
# Epoch 25 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5177
# Epoch 25 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6585
# Epoch 25 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4420
# Epoch 25 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5796
# Epoch 25 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3995
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5987 | F1: 0.5825
# No improvement this validation step.
#
# Epoch 26/60
# Epoch 26 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5156
# Epoch 26 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6547
# Epoch 26 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.4177
# Epoch 26 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5691
# Epoch 26 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3843
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5991 | F1: 0.5506
# No improvement this validation step.
#
# Epoch 27/60
# Epoch 27 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5164
# Epoch 27 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6540
# Epoch 27 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3911
# Epoch 27 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5493
# Epoch 27 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3943
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5789 | F1: 0.5860
# No improvement this validation step.
#
# Epoch 28/60
# Epoch 28 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5000
# Epoch 28 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6447
# Epoch 28 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3707
# Epoch 28 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5462
# Epoch 28 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3924
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6502 | F1: 0.6421
# --- New Best Ensemble Saved (epoch 28) ---
#
# Epoch 29/60
# Epoch 29 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5039
# Epoch 29 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6338
# Epoch 29 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3970
# Epoch 29 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5443
# Epoch 29 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.4029
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6207 | F1: 0.6310
# No improvement this validation step.
#
# Epoch 30/60
# Epoch 30 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.5026
# Epoch 30 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6221
# Epoch 30 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3644
# Epoch 30 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5398
# Epoch 30 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3845
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5583 | F1: 0.5702
# No improvement this validation step.
#
# Epoch 31/60
# Epoch 31 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4698
# Epoch 31 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6374
# Epoch 31 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3684
# Epoch 31 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5380
# Epoch 31 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3754
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5972 | F1: 0.5811
# No improvement this validation step.
#
# Epoch 32/60
# Epoch 32 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4933
# Epoch 32 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6233
# Epoch 32 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3609
# Epoch 32 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5112
# Epoch 32 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3809
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5682 | F1: 0.5682
# No improvement this validation step.
#
# Epoch 33/60
# Epoch 33 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4881
# Epoch 33 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6146
# Epoch 33 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3515
# Epoch 33 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5127
# Epoch 33 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3895
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6335 | F1: 0.6335
# No improvement this validation step.
#
# Epoch 34/60
# Epoch 34 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4990
# Epoch 34 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6112
# Epoch 34 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3380
# Epoch 34 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5114
# Epoch 34 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3860
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6316 | F1: 0.6316
# No improvement this validation step.
#
# Epoch 35/60
# Epoch 35 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4969
# Epoch 35 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6095
# Epoch 35 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3448
# Epoch 35 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4979
# Epoch 35 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3771
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6331 | F1: 0.6430
# No improvement this validation step.
#
# Epoch 36/60
# Epoch 36 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4731
# Epoch 36 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5944
# Epoch 36 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3240
# Epoch 36 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4906
# Epoch 36 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3692
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6577 | F1: 0.6492
# --- New Best Ensemble Saved (epoch 36) ---
#
# Epoch 37/60
# Epoch 37 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4848
# Epoch 37 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.6121
# Epoch 37 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3118
# Epoch 37 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.5036
# Epoch 37 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3653
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6196 | F1: 0.6029
# No improvement this validation step.
#
# Epoch 38/60
# Epoch 38 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4543
# Epoch 38 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5839
# Epoch 38 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3298
# Epoch 38 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4678
# Epoch 38 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3712
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6393 | F1: 0.6393
# No improvement this validation step.
#
# Epoch 39/60
# Epoch 39 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4674
# Epoch 39 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5956
# Epoch 39 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3090
# Epoch 39 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4789
# Epoch 39 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3377
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6376 | F1: 0.6376
# No improvement this validation step.
#
# Epoch 40/60
# Epoch 40 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4476
# Epoch 40 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5974
# Epoch 40 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.3004
# Epoch 40 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4811
# Epoch 40 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3424
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5866 | F1: 0.5866
# No improvement this validation step.
#
# Epoch 41/60
# Epoch 41 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4730
# Epoch 41 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5844
# Epoch 41 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2936
# Epoch 41 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4683
# Epoch 41 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3563
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.5506 | F1: 0.5506
# No improvement this validation step.
#
# Epoch 42/60
# Epoch 42 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4500
# Epoch 42 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5846
# Epoch 42 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2978
# Epoch 42 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4793
# Epoch 42 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3412
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6022 | F1: 0.5859
# No improvement this validation step.
#
# Epoch 43/60
# Epoch 43 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4682
# Epoch 43 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5862
# Epoch 43 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2928
# Epoch 43 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4627
# Epoch 43 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3478
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6587 | F1: 0.6409
# --- New Best Ensemble Saved (epoch 43) ---
#
# Epoch 44/60
# Epoch 44 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4357
# Epoch 44 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5694
# Epoch 44 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2888
# Epoch 44 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4658
# Epoch 44 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3498
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6444 | F1: 0.5922
# No improvement this validation step.
#
# Epoch 45/60
# Epoch 45 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4674
# Epoch 45 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5933
# Epoch 45 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2719
# Epoch 45 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4442
# Epoch 45 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3728
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6512 | F1: 0.6606
# No improvement this validation step.
#
# Epoch 46/60
# Epoch 46 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4494
# Epoch 46 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5826
# Epoch 46 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2726
# Epoch 46 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4601
# Epoch 46 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3563
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6241 | F1: 0.6073
# No improvement this validation step.
#
# Epoch 47/60
# Epoch 47 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4504
# Epoch 47 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5646
# Epoch 47 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2771
# Epoch 47 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4511
# Epoch 47 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3383
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6611 | F1: 0.6345
# --- New Best Ensemble Saved (epoch 47) ---
#
# Epoch 48/60
# Epoch 48 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4464
# Epoch 48 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5686
# Epoch 48 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2687
# Epoch 48 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4373
# Epoch 48 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3494
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6666 | F1: 0.6666
# --- New Best Ensemble Saved (epoch 48) ---
#
# Epoch 49/60
# Epoch 49 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4411
# Epoch 49 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5696
# Epoch 49 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2846
# Epoch 49 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4625
# Epoch 49 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3611
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6692 | F1: 0.6511
# --- New Best Ensemble Saved (epoch 49) ---
#
# Epoch 50/60
# Epoch 50 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4302
# Epoch 50 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5759
# Epoch 50 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2703
# Epoch 50 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4352
# Epoch 50 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3407
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6276 | F1: 0.6207
# No improvement this validation step.
#
# Epoch 51/60
# Epoch 51 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4339
# Epoch 51 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5603
# Epoch 51 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2823
# Epoch 51 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4567
# Epoch 51 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3526
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6454 | F1: 0.6471
# No improvement this validation step.
#
# Epoch 52/60
# Epoch 52 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4519
# Epoch 52 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5708
# Epoch 52 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2748
# Epoch 52 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4454
# Epoch 52 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3203
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6289 | F1: 0.6389
# No improvement this validation step.
#
# Epoch 53/60
# Epoch 53 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4352
# Epoch 53 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5656
# Epoch 53 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2706
# Epoch 53 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4381
# Epoch 53 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3585
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6707 | F1: 0.6793
# --- New Best Ensemble Saved (epoch 53) ---
#
# Epoch 54/60
# Epoch 54 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4622
# Epoch 54 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5759
# Epoch 54 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2822
# Epoch 54 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4086
# Epoch 54 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3425
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6752 | F1: 0.6657
# --- New Best Ensemble Saved (epoch 54) ---
#
# Epoch 55/60
# Epoch 55 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4294
# Epoch 55 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5651
# Epoch 55 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2730
# Epoch 55 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4424
# Epoch 55 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3368
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6390 | F1: 0.6217
# No improvement this validation step.
#
# Epoch 56/60
# Epoch 56 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4451
# Epoch 56 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5361
# Epoch 56 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2776
# Epoch 56 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4307
# Epoch 56 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3418
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6554 | F1: 0.6554
# No improvement this validation step.
#
# Epoch 57/60
# Epoch 57 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4361
# Epoch 57 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5627
# Epoch 57 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2748
# Epoch 57 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4431
# Epoch 57 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3512
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6611 | F1: 0.6794
# No improvement this validation step.
#
# Epoch 58/60
# Epoch 58 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4366
# Epoch 58 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5679
# Epoch 58 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2585
# Epoch 58 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4449
# Epoch 58 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3482
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6242 | F1: 0.6073
# No improvement this validation step.
#
# Epoch 59/60
# Epoch 59 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4529
# Epoch 59 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5918
# Epoch 59 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2683
# Epoch 59 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4419
# Epoch 59 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3552
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6306 | F1: 0.6235
# No improvement this validation step.
#
# Epoch 60/60
# Epoch 60 - Train model 0:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 0 train loss: 0.4322
# Epoch 60 - Train model 1:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 1 train loss: 0.5723
# Epoch 60 - Train model 2:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 2 train loss: 0.2379
# Epoch 60 - Train model 3:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 3 train loss: 0.4448
# Epoch 60 - Train model 4:   0%|          | 0/175 [00:00<?, ?it/s]
# Model 4 train loss: 0.3486
# Validating:   0%|          | 0/37 [00:00<?, ?it/s]
# Validation - Dice: 0.6283 | F1: 0.6114
# No improvement this validation step.
# Loaded checkpoint: /kaggle/working/checkpoints_improved/best_model_0.pth
# Loaded checkpoint: /kaggle/working/checkpoints_improved/best_model_1.pth
# Loaded checkpoint: /kaggle/working/checkpoints_improved/best_model_2.pth
# Loaded checkpoint: /kaggle/working/checkpoints_improved/best_model_3.pth
# Loaded checkpoint: /kaggle/working/checkpoints_improved/best_model_4.pth
# Collecting validation predictions for tuning...
# Collecting val preds:   0%|          | 0/37 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_55/3722276944.py in <cell line: 0>()
#     650
#     651     print("Collecting validation predictions for tuning...")
# --> 652     preds_per_model, gts = collect_val_predictions(models, val_loader)
#     653     print("Tuning threshold and min-component size on validation set...")
#     654     best_thresh, best_minvox, best_score = tune_threshold_and_minvox(preds_per_model, gts,
#
# /tmp/ipykernel_55/3722276944.py in collect_val_predictions(models, loader)
#     444             gt_unp = unpad_tensor(masks, pad)
#     445             gts.append(gt_unp.cpu().numpy()[0,0].astype(np.uint8))
# --> 446     preds_per_model = [np.stack(lst, axis=0) for lst in preds_per_model]
#     447     return preds_per_model, gts
#     448
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/shape_base.py in stack(arrays, axis, out, dtype, casting)
#     446     shapes = {arr.shape for arr in arrays}
#     447     if len(shapes) != 1:
# --> 448         raise ValueError('all input arrays must have the same shape')
#     449
#     450     result_ndim = arrays[0].ndim + 1
#
# ValueError: all input arrays must have the same shape
