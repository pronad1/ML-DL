# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/rajshahi_housing_final.csv')

# %%
df
# Out:
#           Location  Size (sqft)  Bedrooms  Bathrooms  Year Built Garage  \
# 0             Paba         1361         3          2        2012    Yes
# 1     Shah Makhdum          789         1          1        2017     No
# 2          Motihar         2107         3          1        2000     No
# 3     Shah Makhdum         2356         5          1        2003     No
# 4     Shah Makhdum         2159         3          3        2002    Yes
# ...            ...          ...       ...        ...         ...    ...
# 9995       Rajpara         2857         2          2        1991     No
# 9996       Motihar         2797         1          1        2006     No
# 9997       Rajpara          630         1          3        2006     No
# 9998          Paba         1211         1          1        2009    Yes
# 9999       Motihar         2464         5          2        2004    Yes
#
#       Balcony Garden Flooring_Type  Kitchen  Dining Lift  Floor     Price
# ...

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-148b22e0-c1c7-49e2-93e4-029b312627d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-148b22e0-c1c7-49e2-93e4-029b312627d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### For Connect with kaggle

# %%
#create a kaggle folder
! mkdir  ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %% [markdown]
# ### For check connection

# %%
# !ls -l ~/.kaggle/kaggle.json
# Out:
# -rw-r--r-- 1 root root 71 Aug 24 15:40 /root/.kaggle/kaggle.json

# %% [markdown]
# ### Paste a API from kaggle that I want to use and I get this from copy API command in any data set in kaggle

# %%
# !kaggle datasets download -d wobotintelligence/face-mask-detection-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/wobotintelligence/face-mask-detection-dataset
# License(s): CC0-1.0
# ...
# 100% 2.49G/2.50G [00:21<00:00, 282MB/s]
# 100% 2.50G/2.50G [00:21<00:00, 126MB/s]
